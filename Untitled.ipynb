# %%
from agents.actor_critic_agents import SAC_Discrete
from agents.Trainer import Trainer
import numpy as np
import torch
import pickle

# %%
config = {}
trainer = Trainer(config, [SAC_Discrete])

# %%
for agent_number, agent_class in enumerate(trainer.agents):
    print (agent_class)
# Out:
# <module 'agents.actor_critic_agents.SAC_Discrete' from 'E:\\SAC-Discrete\\agents\\actor_critic_agents\\SAC_Discrete.py'>

# %%
agent_class.
# Out:
# agents.actor_critic_agents.SAC.SAC

# %%
"HER" not in "SAC"
# Out:
# True

# %%
# Out:
#   File "<ipython-input-58-a525a8436486>", line 1
#     agent_number, agent_class = [for x in list(enumerate(trainer.agents))]
#                                    ^
# SyntaxError: invalid syntax

# %%
a = torch.randn(4,4)
a
# Out:
# tensor([[-0.4503, -1.0475,  1.9996, -2.1267],
#         [-1.1760,  1.7752, -0.5424, -1.5240],
#         [ 0.4869, -0.0146,  0.5840,  0.1347],
#         [-1.0578,  1.0279,  0.1384, -2.4102]])

# %%
torch.argmax(a, dim = -1)
# Out:
# tensor([2, 1, 2, 1])

# %%
torch.argmax?

# %%
dim(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-59994409e4b2> in <module>
# ----> 1 dim(a)
#
# NameError: name 'dim' is not defined

# %%
torch.Tensor.dim(a)
# Out:
# 2

# %%
# !cd results/

# %%
# %cd results/data_and_graphs/
# Out:
# E:\SAC-Discrete\results\data_and_graphs

# %%
with open('Cart_Pole_Results_Data.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
data
# Out:
# {'DQN': [[[10.0,
#     12.0,
#     11.0,
#     10.0,
#     10.0,
#     11.0,
#     10.0,
#     9.0,
#     10.0,
#     8.0,
#     10.0,
#     10.0,
#     10.0,
#     10.0,
#     9.0,
#     10.0,
#     9.0,
#     10.0,
#     11.0,
#     10.0,
#     13.0,
#     10.0,
#     10.0,
#     8.0,
#     10.0,
#     11.0,
#     10.0,
#     12.0,
#     11.0,
#     9.0,
#     8.0,
#     10.0,
#     13.0,
#     10.0,
#     9.0,
#     9.0,
#     11.0,
#     10.0,
#     9.0,
#     10.0,
#     10.0,
#     10.0,
#     11.0,
#     9.0,
#     10.0,
#     9.0,
#     10.0,
#     8.0,
#     10.0,
#     9.0,
#     9.0,
#     10.0,
#     9.0,
#     10.0,
#     9.0,
#     10.0,
#     9.0,
#     9.0,
#     12.0,
#     9.0,
#     9.0,
#     9.0,
#     13.0,
#     24.0,
#     23.0,
#     13.0,
#     14.0,
#     12.0,
#     13.0,
#     14.0,
#     13.0,
#     14.0,
#     24.0,
#     20.0,
#     18.0,
#     17.0,
#     17.0,
#     15.0,
#     22.0,
#     42.0,
#     12.0,
#     31.0,
#     38.0,
#     54.0,
# ...

# %%
from nn_builder.pytorch.NN import NN   
model = NN(input_dim=5, layers_info=[10, 10, 1], output_activation=None, hidden_activations="relu", 
           dropout=0.0, initialiser="xavier", batch_norm=False)

# %%
dir(model)
# Out:
# ['__abstractmethods__',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_cache',
#  '_abc_negative_cache',
#  '_abc_negative_cache_version',
#  '_abc_registry',
#  '_apply',
#  '_backward_hooks',
#  '_buffers',
#  '_forward_hooks',
#  '_forward_pre_hooks',
#  '_get_name',
#  '_load_from_state_dict',
#  '_load_state_dict_pre_hooks',
#  '_modules',
#  '_named_members',
#  '_parameters',
#  '_register_load_state_dict_pre_hook',
#  '_register_state_dict_hook',
#  '_replicate_for_data_parallel',
#  '_save_to_state_dict',
#  '_slow_forward',
# ...

# %%
model.state_dict()
# Out:
# OrderedDict([('hidden_layers.0.weight',
#               tensor([[-0.1324,  0.4516,  0.1765,  0.3039,  0.2234],
#                       [-0.1521, -0.1330, -0.5212,  0.3427,  0.5022],
#                       [ 0.4327, -0.4461,  0.0282, -0.4458, -0.3482],
#                       [-0.3685,  0.2161, -0.3769, -0.0138,  0.0266],
#                       [ 0.4077, -0.4781, -0.4342, -0.3672,  0.4427],
#                       [-0.2273,  0.5335,  0.2287,  0.0801, -0.0047],
#                       [-0.1250,  0.0794, -0.1444, -0.0044,  0.0807],
#                       [-0.4947, -0.3315,  0.5107, -0.5133, -0.0454],
#                       [ 0.6256,  0.2285,  0.0179, -0.5481,  0.3133],
#                       [-0.4505, -0.1795, -0.2122, -0.0937,  0.0069]])),
#              ('hidden_layers.0.bias',
#               tensor([ 0.2860,  0.4446,  0.1775,  0.0604,  0.2999, -0.2633,  0.0833, -0.3467,
#                       -0.3100, -0.2310])),
#              ('hidden_layers.1.weight',
# ...
